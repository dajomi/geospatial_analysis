# %%
import rasterio

# %%
dataset = rasterio.open('C:/Users/Administrator/Desktop/packages/Natural_Earth_quick_start/50m_raster/NE1_50M_SR_W/NE1_50M_SR_W.tif')

# %%
dataset.count
# Out:
# 3

# %%
dataset.width # 열의 수
# Out:
# 10800

# %%
dataset.height # 행의 수
# Out:
# 5400

# %%
dataset.bounds # 공간 경계의 박스를 미터 단위로 나타냄
# Out:
# BoundingBox(left=-179.99999999999997, bottom=-89.99999999998201, right=179.99999999996405, top=90.0)

# %%
dataset.crs
# Out:
# CRS.from_epsg(4326)

# %%
band1 = dataset.read(1)
band1
# Out:
# array([[124, 124, 124, ..., 124, 124, 124],
#        [118, 118, 118, ..., 118, 118, 118],
#        [118, 118, 118, ..., 118, 118, 118],
#        ...,
#        [242, 241, 241, ..., 242, 241, 242],
#        [243, 243, 243, ..., 242, 243, 243],
#        [245, 245, 244, ..., 244, 245, 244]], dtype=uint8)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(band1)
plt.show()
